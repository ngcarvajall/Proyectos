# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import requests

import sys
sys.path.append('c:\\Users\\DELL\\Git\\Proyecto5-GOAT_MJ_LJ\\src')  #doy la direccion de mi funcion

# imporot mi funcion
import support as s
# Para trabajar con archivos dotenv y los tokens
# -----------------------------------------------------------------------
import os
import dotenv
# dotenv.load_dotenv() ### reconoce un archivo .env y que tiene información
import json

# %%
dotenv.load_dotenv()
api_token = os.getenv('api_token')

# %%
url = "https://basketapi1.p.rapidapi.com/api/basketball/tournament/132/season/54105/standings/total"

headers = {
	"x-rapidapi-key": api_token,
	"x-rapidapi-host": "basketapi1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

responsa = response.json()

# %%
with open('league_2024.json', 'w') as archivo_json:
    json.dump(responsa, archivo_json, indent=4)

# %%
responsa.keys()
# Out:
# dict_keys(['standings'])

# %%
responsa['standings'][8]['rows']
# Out:
# [{'team': {'name': 'Boston Celtics',
#    'slug': 'boston-celtics',
#    'shortName': 'Celtics',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 136774,
#    'nameCode': 'BOS',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3422,
#    'teamColors': {'primary': '#008348',
#     'secondary': '#ffffff',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'بوسطن سيلتيكس',
#      'ru': 'Бостон Селтикс'},
#     'shortNameTranslation': {}}},
#   'descriptions': [],
#   'position': 1,
#   'matches': 82,
#   'wins': 64,
#   'scoresFor': 9887,
#   'scoresAgainst': 8957,
#   'percentage': 0.78,
#   'gamesBehind': 0,
#   'streak': 2,
#   'id': 907460,
#   'losses': 18,
#   'draws': 0,
#   'scoreDiffFormatted': '+930'},
#  {'team': {'name': 'Denver Nuggets',
#    'slug': 'denver-nuggets',
#    'shortName': 'Nuggets',
#    'gender': 'M',
# ...

# %%
df = s.extraer_datos_equipos_df(responsa,30)

# %%
df['Nombre_comun'].unique()
# Out:
# array(['Celtics', 'Nuggets', 'Thunder', 'Timberwolves', 'Clippers',
#        'Mavericks', 'Knicks', 'Bucks', 'Pelicans', 'Suns', 'Cavaliers',
#        'Pacers', 'Lakers', 'Magic', '76ers', 'Warriors', 'Heat', 'Kings',
#        'Rockets', 'Bulls', 'Hawks', 'Nets', 'Jazz', 'Grizzlies',
#        'Raptors', 'Spurs', 'Hornets', 'Trail Blazers', 'Wizards',
#        'Pistons'], dtype=object)

# %%
df['Codigo_equipo'].unique()
# Out:
# array(['BOS', 'DEN', 'OKC', 'MIN', 'LAC', 'DAL', 'NYK', 'MIL', 'NOP',
#        'PHX', 'CLE', 'IND', 'LAL', 'ORL', 'PHI', 'GSW', 'MIA', 'SAC',
#        'HOU', 'CHI', 'ATL', 'BKN', 'UTA', 'MEM', 'TOR', 'SAS', 'CHA',
#        'POR', 'WAS', 'DET'], dtype=object)

# %%
df.head()
# Out:
#                    Equipo  Nombre_comun Codigo_equipo  Posicion  Partidos  \
# 0          Boston Celtics       Celtics           BOS         1        82
# 1          Denver Nuggets       Nuggets           DEN         2        82
# 2   Oklahoma City Thunder       Thunder           OKC         3        82
# 3  Minnesota Timberwolves  Timberwolves           MIN         4        82
# 4    Los Angeles Clippers      Clippers           LAC         5        82
#
#    Victorias  Derrotas  Porcentaje_vic
# 0         64        18           0.780
# 1         57        25           0.695
# 2         57        25           0.695
# 3         56        26           0.683
# 4         51        31           0.622

# %%
df.to_csv('../datos/equipos_2024.csv', index=False)
