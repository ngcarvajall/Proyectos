# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd

# Otros objetivos
# -----------------------------------------------------------------------
import math
import sys
import os
sys.path.append('..\\src') #pongo los 2 puntos para que salga de la carpeta
import soporte_funciones as sf
# Gráficos
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
pd.set_option('display.max_columns', None)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Primera exploración

# %% [markdown]
# ### Observaciones:
# - Hay numerosas columnas que me cargué al ir explorando su valor a mis datos.
# - Tenía 8 duplicados, que eliminé.
# - La columna de provincia la eliminé porque en realidad se busca un modelo para Madrid, por lo que esta no era referente a nuestro caso. Además, eliminé los datos fuera de Madrid.

# %%
df = pd.read_csv('..\\datos\\api_rent_madrid.csv', sep = ';')
df.head()
# Out:
#    propertyCode  numPhotos  price propertyType operation   size  exterior  \
# 0      98903350         33  550.0       chalet      rent  371.0     False
# 1      91615378         12  750.0         flat      rent   60.0      True
# 2      88363329         21  750.0         flat      rent   70.0      True
# 3      98621753         28  400.0    penthouse      rent   67.0      True
# 4      98222714         22  450.0         flat      rent   89.0     False
#
#    rooms  bathrooms                          address province  \
# 0      6          3             Numancia de la Sagra   Toledo
# 1      1          1  Calle de Alejandro Villegas, 23   Madrid
# 2      2          1               Gregorio izquierdo   Madrid
# 3      2          2                     Calle Madrid   Madrid
# 4      2          1                     Calle Arroyo   Toledo
#
#                  municipality country     latitude    longitude  showAddress  \
# 0        Numancia de la Sagra      es  400.675.955  -38.225.891        False
# 1                      Madrid      es  404.646.164  -36.489.179         True
# 2  San Sebastián de los Reyes      es  405.500.865  -36.278.085        False
# 3       Villamanrique de Tajo      es   40.069.197   -3.241.383        False
# 4                       Recas      es  400.536.974  -39.912.159        False
#
#    distance                                        description hasVideo  \
# 0     40116  UGENA VILLAGE INMOBILIARIA GESTIONA en exclusi...    False
# 1      7037  LOFT DE DISEÑO. Orientación Este. Muy soleado ...    False
# 2     16145  Estupendo piso muy iluminado, recientemente re...     True
# 3     55041  A estrenar ático con piscina en Calle Madrid, ...    False
# 4     47186  REDPISO alquila esta vivienda situada en el mu...    False
#
#   status newDevelopment  priceByArea  \
# 0   good          False          1.0
# 1   good          False         13.0
# 2   good          False         11.0
# 3   good          False          6.0
# 4   good          False          5.0
#
#                                         detailedType  \
# 0  {'typology': 'chalet', 'subTypology': 'indepen...
# 1                               {'typology': 'flat'}
# 2                               {'typology': 'flat'}
# 3   {'typology': 'flat', 'subTypology': 'penthouse'}
# 4                               {'typology': 'flat'}
#
#                                       suggestedTexts hasPlan has3DTour has360  \
# 0  {'subtitle': 'Numancia de la Sagra', 'title': ...   False     False  False
# 1  {'subtitle': 'Canillas, Madrid', 'title': 'Pis...   False     False  False
# 2  {'subtitle': 'Centro Urbano, San Sebastián de ...    True     False  False
# 3  {'subtitle': 'Villamanrique de Tajo', 'title':...   False     False   True
# 4  {'subtitle': 'Recas', 'title': 'Piso en Calle ...   False     False  False
#
#   hasStaging superTopHighlight topNewDevelopment externalReference floor  \
# 0      False             False             False               NaN   NaN
# 1      False             False             False              AV23     3
# 2      False             False             False               NaN    bj
# 3      False             False             False             90004     2
# 4      False             False             False   RP1882022101719     2
#
#         district neighborhood hasLift  \
# 0            NaN          NaN     NaN
# 1      Hortaleza     Canillas    True
# 2  Centro Urbano          NaN   False
# 3            NaN          NaN   False
# 4            NaN          NaN    True
#
#                                         parkingSpace labels  \
# 0                                                NaN    NaN
# 1                                                NaN    NaN
# 2                                                NaN    NaN
# 3                                                NaN    NaN
# 4  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
#
#   newDevelopmentFinished
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %% [markdown]
# Tenemos 450 datos, 38 columnas

# %%
df.shape
# Out:
# (450, 38)

# %% [markdown]
# Una media de precio de 700 euros, una mínima de 340 y una máxima de 750.

# %%
df.describe()
# Out:
#        propertyCode   numPhotos       price        size       rooms  \
# count  4.500000e+02  450.000000  450.000000  450.000000  450.000000
# mean   9.463515e+07   21.900000  671.797778   68.237778    1.700000
# std    1.385817e+07    9.670346   85.100603   35.662557    0.970041
# min    6.666960e+05    0.000000  340.000000   20.000000    0.000000
# 25%    9.756495e+07   15.000000  640.000000   47.250000    1.000000
# 50%    9.866032e+07   21.000000  700.000000   62.000000    2.000000
# 75%    9.889432e+07   28.000000  740.000000   80.000000    2.000000
# max    9.893968e+07   72.000000  750.000000  371.000000    6.000000
#
#         bathrooms      distance  priceByArea
# count  450.000000    450.000000   432.000000
# mean     1.213333  22455.771111    11.863426
# std      0.441500  17001.691666     5.360971
# min      1.000000    183.000000     1.000000
# 25%      1.000000   7104.250000     8.000000
# 50%      1.000000  20294.000000    11.000000
# 75%      1.000000  34979.750000    15.000000
# max      3.000000  59919.000000    33.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   propertyCode            450 non-null    int64
#  1   numPhotos               450 non-null    int64
#  2   price                   450 non-null    float64
#  3   propertyType            450 non-null    object
#  4   operation               450 non-null    object
#  5   size                    450 non-null    float64
#  6   exterior                450 non-null    bool
#  7   rooms                   450 non-null    int64
#  8   bathrooms               450 non-null    int64
#  9   address                 450 non-null    object
#  10  province                450 non-null    object
#  11  municipality            450 non-null    object
#  12  country                 450 non-null    object
#  13  latitude                450 non-null    object
#  14  longitude               450 non-null    object
#  15  showAddress             450 non-null    bool
#  16  distance                450 non-null    int64
#  17  description             449 non-null    object
#  18  hasVideo                432 non-null    object
#  19  status                  432 non-null    object
#  20  newDevelopment          432 non-null    object
#  21  priceByArea             432 non-null    float64
#  22  detailedType            432 non-null    object
#  23  suggestedTexts          432 non-null    object
#  24  hasPlan                 432 non-null    object
#  25  has3DTour               432 non-null    object
#  26  has360                  432 non-null    object
#  27  hasStaging              432 non-null    object
#  28  superTopHighlight       432 non-null    object
#  29  topNewDevelopment       432 non-null    object
#  30  externalReference       345 non-null    object
#  31  floor                   366 non-null    object
#  32  district                338 non-null    object
#  33  neighborhood            174 non-null    object
#  34  hasLift                 419 non-null    object
#  35  parkingSpace            140 non-null    object
#  36  labels                  30 non-null     object
#  37  newDevelopmentFinished  17 non-null     object
# dtypes: bool(2), float64(3), int64(5), object(28)
# memory usage: 127.6+ KB

# %% [markdown]
# Tengo nulos presentes en varias categorías. En unas, pocoso nulos pero en otras hay muchos, por ejemplo: labels, newDevelopmentFinished.

# %%
df.isna().sum()
# Out:
# propertyCode                0
# numPhotos                   0
# price                       0
# propertyType                0
# operation                   0
# size                        0
# exterior                    0
# rooms                       0
# bathrooms                   0
# address                     0
# province                    0
# municipality                0
# country                     0
# latitude                    0
# longitude                   0
# showAddress                 0
# distance                    0
# description                 1
# hasVideo                   18
# status                     18
# newDevelopment             18
# priceByArea                18
# detailedType               18
# suggestedTexts             18
# hasPlan                    18
# has3DTour                  18
# has360                     18
# hasStaging                 18
# superTopHighlight          18
# topNewDevelopment          18
# externalReference         105
# floor                      84
# district                  112
# neighborhood              276
# hasLift                    31
# parkingSpace              310
# labels                    420
# newDevelopmentFinished    433
# dtype: int64

# %% [markdown]
# Con el nunique puedo darme cuenta de algunas columnas que, en realidad no aportan nada, como operation o country ya que tienen un único valor.
#
# Para el caso de operation, hace sentido que sea solo único ya que todos son pisos de alquiler. Country, por igual, hace referencia a un único país por lo que no vale la pena mantenerla.
#
# Las demás sigo explorando.

# %%
df.nunique()
# Out:
# propertyCode              442
# numPhotos                  49
# price                      63
# propertyType                6
# operation                   1
# size                      103
# exterior                    2
# rooms                       6
# bathrooms                   3
# address                   405
# province                    5
# municipality               96
# country                     1
# latitude                  433
# longitude                 433
# showAddress                 2
# distance                  430
# description               427
# hasVideo                    2
# status                      3
# newDevelopment              2
# priceByArea                31
# detailedType               10
# suggestedTexts            395
# hasPlan                     2
# has3DTour                   2
# has360                      2
# hasStaging                  1
# superTopHighlight           1
# topNewDevelopment           1
# externalReference         335
# floor                      13
# district                   96
# neighborhood               74
# hasLift                     2
# parkingSpace                5
# labels                      1
# newDevelopmentFinished      2
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#      propertyCode  numPhotos  price propertyType operation   size  exterior  \
# 253      98068981         19  692.0         flat      rent   83.0      True
# 254      98069014         19  670.0         flat      rent   79.0      True
# 255      98288656         14  609.0         flat      rent   56.0      True
# 256      98069020         19  718.0         flat      rent   86.0      True
# 300      98889734         48  470.0         flat      rent   80.0     False
# 301      98911140         23  750.0         flat      rent  109.0      True
# 302      98913105         24  550.0         flat      rent   76.0      True
# 350      95224372         32  400.0         flat      rent  100.0      True
#
#      rooms  bathrooms                   address province         municipality  \
# 253      2          2  Calle Valle de Ambles, 2   Madrid    Torrejón de Ardoz
# 254      2          2  Calle Valle de Ambles, 2   Madrid    Torrejón de Ardoz
# 255      1          1     Calle Álvaro Mutis, 1   Madrid    Alcalá de Henares
# 256      2          2  Calle Valle de Ambles, 2   Madrid    Torrejón de Ardoz
# 300      1          1                Fuensalida   Toledo           Fuensalida
# 301      2          2                  Hospital   Madrid            Valdemoro
# 302      2          1                    Yuncos   Toledo               Yuncos
# 350      3          2       Cabañas de la Sagra   Toledo  Cabañas de la Sagra
#
#     country     latitude    longitude  showAddress  distance  \
# 253      es  404.430.651  -34.659.877         True     20294
# 254      es  404.430.651  -34.659.877         True     20294
# 255      es  405.126.166  -33.694.194         True     30186
# 256      es  404.430.651  -34.659.877         True     20294
# 300      es  400.493.725  -42.105.716        False     59351
# 301      es  401.969.978  -36.896.474        False     24455
# 302      es  400.947.108  -38.715.189        False     38544
# 350      es   40.009.603  -39.515.398        False     49933
#
#                                            description hasVideo  \
# 253  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
# 254  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
# 255  Vivienda adaptada. Certificado 33% de minusval...    False
# 256  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
# 300  ESPECTACULAR PISO DE UN DORMITORIO TOTALMENTE ...    False
# 301  Características de la vivienda: urbanización p...    False
# 302  IBC Alquila piso amueblado en zona centro de Y...    False
# 350  INMOBILIARIA BUY HOUSE COMERCIALIZA PRECIOSO P...    False
#
#              status newDevelopment  priceByArea          detailedType  \
# 253  newdevelopment           True          8.0  {'typology': 'flat'}
# 254  newdevelopment           True          8.0  {'typology': 'flat'}
# 255  newdevelopment           True         11.0  {'typology': 'flat'}
# 256  newdevelopment           True          8.0  {'typology': 'flat'}
# 300            good          False          6.0  {'typology': 'flat'}
# 301            good          False          7.0  {'typology': 'flat'}
# 302            good          False          7.0  {'typology': 'flat'}
# 350            good          False          4.0  {'typology': 'flat'}
#
#                                         suggestedTexts hasPlan has3DTour  \
# 253  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
# 254  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
# 255  {'subtitle': 'Espartales, Alcalá de Henares', ...    True     False
# 256  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
# 300        {'subtitle': 'Fuensalida', 'title': 'Piso'}   False     False
# 301  {'subtitle': 'Hospital, Valdemoro', 'title': '...   False     False
# 302            {'subtitle': 'Yuncos', 'title': 'Piso'}   False     False
# 350  {'subtitle': 'Cabañas de la Sagra', 'title': '...    True     False
#
#     has360 hasStaging superTopHighlight topNewDevelopment   externalReference  \
# 253  False      False             False             False                VT02
# 254  False      False             False             False                VT07
# 255  False      False             False             False                 VT3
# 256  False      False             False             False                VT06
# 300  False      False             False             False                 NaN
# 301  False      False             False             False  Pisoalquileragatha
# 302  False      False             False             False                5421
# 350  False      False             False             False              3978-1
#
#     floor    district neighborhood hasLift  \
# 253   NaN    Suroeste          NaN    True
# 254   NaN    Suroeste          NaN    True
# 255    bj  Espartales          NaN    True
# 256   NaN    Suroeste          NaN    True
# 300     1         NaN          NaN    True
# 301     3    Hospital          NaN    True
# 302     2         NaN          NaN    True
# 350     2         NaN          NaN    True
#
#                                           parkingSpace labels  \
# 253  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 254  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 255                                                NaN    NaN
# 256  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 300                                                NaN    NaN
# 301  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 302  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 350  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
#
#     newDevelopmentFinished
# 253                   True
# 254                   True
# 255                   True
# 256                   True
# 300                    NaN
# 301                    NaN
# 302                    NaN
# 350                    NaN

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Después de cargarme los duplicados, me quedan 442 casas.

# %%
sf.exploracion_dataframe(df, 'price')
# Out:
# El número de datos es 442 y el de columnas es 38
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 0
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#                           %_nulos
# description              0.226244
# hasVideo                 4.072398
# status                   4.072398
# newDevelopment           4.072398
# priceByArea              4.072398
# detailedType             4.072398
# suggestedTexts           4.072398
# hasPlan                  4.072398
# has3DTour                4.072398
# has360                   4.072398
# hasStaging               4.072398
# superTopHighlight        4.072398
# topNewDevelopment        4.072398
# externalReference       23.529412
# floor                   18.325792
# district                24.660633
# neighborhood            60.633484
# hasLift                  7.013575
# parkingSpace            69.683258
# labels                  93.212670
# newDevelopmentFinished  97.058824
#  .....................
#
# Los tipos de las columnas son:
#                        tipo_dato
# propertyCode               int64
# numPhotos                  int64
# price                    float64
# propertyType              object
# operation                 object
# size                     float64
# exterior                    bool
# rooms                      int64
# bathrooms                  int64
# address                   object
# province                  object
# municipality              object
# country                   object
# latitude                  object
# longitude                 object
# showAddress                 bool
# distance                   int64
# description               object
# hasVideo                  object
# status                    object
# newDevelopment            object
# priceByArea              float64
# detailedType              object
# suggestedTexts            object
# hasPlan                   object
# has3DTour                 object
# has360                    object
# hasStaging                object
# superTopHighlight         object
# topNewDevelopment         object
# externalReference         object
# floor                     object
# district                  object
# neighborhood              object
# hasLift                   object
# parkingSpace              object
# labels                    object
# newDevelopmentFinished    object
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna propertyType tiene las siguientes valore únicos:
#               count
# propertyType
# flat            348
# studio           48
# duplex           19
# penthouse        16
# chalet            9
# countryHouse      2
# La columna operation tiene las siguientes valore únicos:
#            count
# operation
# rent         442
# La columna address tiene las siguientes valore únicos:
#                                  count
# address
# Calle Valle de Ambles, 2             7
# El Quiñón                            4
# Calle de Honduras                    3
# Calle de Sáhara                      3
# Calle de Rocafort                    2
# ...                                ...
# Calle Isaac Albéniz                  1
# Calle de la Gavia Seca               1
# Calle de Villajoyosa                 1
# Calle de los Sagrados Corazones      1
# Calle de Isabel Rosillo, 11          1
#
# [405 rows x 1 columns]
# La columna province tiene las siguientes valore únicos:
#              count
# province
# Madrid         353
# Toledo          59
# Guadalajara     21
# Segovia          8
# Ávila            1
# La columna municipality tiene las siguientes valore únicos:
#                          count
# municipality
# Madrid                     170
# Alcalá de Henares           22
# Parla                       14
# Seseña                      14
# Aranjuez                    11
# ...                        ...
# Los Santos de la Humosa      1
# Mataelpino                   1
# Los Molinos                  1
# Borox                        1
# Alcobendas                   1
#
# [96 rows x 1 columns]
# La columna country tiene las siguientes valore únicos:
#          count
# country
# es         442
# La columna latitude tiene las siguientes valore únicos:
#              count
# latitude
# 404.430.651      7
# 403.809.876      2
# 403.082.527      2
# 402.003.307      2
# 400.493.725      1
# ...            ...
# 404.626.558      1
# 403.782.048      1
# 403.566.848      1
# 40.408.986       1
# 405.430.027      1
#
# [433 rows x 1 columns]
# La columna longitude tiene las siguientes valore únicos:
#              count
# longitude
# -34.659.877      7
# -36.338.528      2
# -37.365.244      2
# -36.919.489      2
# -42.105.716      1
# ...            ...
# -34.833.464      1
# -3.618.842       1
# -36.899.208      1
# -37.381.489      1
# -36.356.712      1
#
# [433 rows x 1 columns]
# La columna description tiene las siguientes valore únicos:
#                                                     count
# description
# VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar con...      7
# PROMOCIÓN: 1 MES DE ALQUILER GRATIS si reservas...      2
# Nuevo curso, nuevo hogar ¡con hasta 1 MES GRATI...      2
# ¡ALQUILA SIN COMISIÓN DE AGENCIA! Se alquilan v...      2
# ESTUDIO HOME MADRID OFRECE Local Vivienda tipo ...      2
# ...                                                   ...
# "PROMOCIÓN: 1 mes de alquiler GRATIS. Y además,...      1
# "PROMOCIÓN: 1 mes de alquiler GRATIS. Y además,...      1
# "PROMOCIÓN: 1 mes de alquiler GRATIS. Y además,...      1
# "PROMOCIÓN: 1 mes de alquiler GRATIS. Y además,...      1
# Se alquila bonita vivienda de 62 m2 (58m2 útile...      1
#
# [427 rows x 1 columns]
# La columna hasVideo tiene las siguientes valore únicos:
#           count
# hasVideo
# False       306
# True        118
# La columna status tiene las siguientes valore únicos:
#                 count
# status
# good              409
# newdevelopment     13
# renew               2
# La columna newDevelopment tiene las siguientes valore únicos:
#                 count
# newDevelopment
# False             411
# True               13
# La columna detailedType tiene las siguientes valore únicos:
#                                                     count
# detailedType
# {'typology': 'flat'}                                  336
# {'typology': 'flat', 'subTypology': 'studio'}          46
# {'typology': 'flat', 'subTypology': 'penthouse'}       16
# {'typology': 'flat', 'subTypology': 'duplex'}          15
# {'typology': 'chalet', 'subTypology': 'terraced...      5
# {'typology': 'chalet', 'subTypology': 'independ...      2
# {'typology': 'chalet'}                                  1
# {'typology': 'countryHouse', 'subTypology': 'co...      1
# {'typology': 'chalet', 'subTypology': 'semideta...      1
# {'typology': 'countryHouse', 'subTypology': 'ca...      1
# La columna suggestedTexts tiene las siguientes valore únicos:
#                                                     count
# suggestedTexts
# {'subtitle': 'Suroeste, Torrejón de Ardoz', 'ti...      7
# {'subtitle': 'El Quiñón, Seseña', 'title': 'Piso'}      4
# {'subtitle': 'Las Sedas - El Olivar, Alcalá de ...      3
# {'subtitle': 'Los Rosales, Madrid', 'title': 'P...      3
# {'subtitle': 'Villa del Prado', 'title': 'Ático...      2
# ...                                                   ...
# {'subtitle': 'Noroeste, Torrejón de Ardoz', 'ti...      1
# {'subtitle': 'Casco Histórico de Vallecas, Madr...      1
# {'subtitle': 'Los Rosales, Madrid', 'title': 'P...      1
# {'subtitle': 'Puerta del Ángel, Madrid', 'title...      1
# {'subtitle': 'Alcobendas Centro, Alcobendas', '...      1
#
# [395 rows x 1 columns]
# La columna hasPlan tiene las siguientes valore únicos:
#          count
# hasPlan
# False      293
# True       131
# La columna has3DTour tiene las siguientes valore únicos:
#            count
# has3DTour
# False        418
# True           6
# La columna has360 tiene las siguientes valore únicos:
#         count
# has360
# False     337
# True       87
# La columna hasStaging tiene las siguientes valore únicos:
#             count
# hasStaging
# False         424
# La columna superTopHighlight tiene las siguientes valore únicos:
#                    count
# superTopHighlight
# False                424
# La columna topNewDevelopment tiene las siguientes valore únicos:
#                    count
# topNewDevelopment
# False                424
# La columna externalReference tiene las siguientes valore únicos:
#                          count
# externalReference
# CG-91792-0001                2
# 6012-VI-011-008-000-003      2
# 3,80811E+11                  2
# 7258340-AL                   1
# 6123                         1
# ...                        ...
# 2805-024850-01               1
# 45-00938                     1
# 2815-001921-04               1
# 2001/20010001/531            1
# CH-95178-0001                1
#
# [335 rows x 1 columns]
# La columna floor tiene las siguientes valore únicos:
#        count
# floor
# 1         94
# 2         75
# bj        67
# 3         59
# 4         36
# 5         11
# en         6
# 8          5
# 6          4
# st         1
# 7          1
# 14         1
# ss         1
# La columna district tiene las siguientes valore únicos:
#                                  count
# district
# Centro                              48
# Villaverde                          23
# Puente de Vallecas                  17
# El Quiñón                           13
# Tetuán                              13
# ...                                ...
# Juan de Austria                      1
# Montserrat - Parque Empresarial      1
# La Montaña-El Cortijo                1
# Zona Industrial                      1
# Alcobendas Centro                    1
#
# [96 rows x 1 columns]
# La columna neighborhood tiene las siguientes valore únicos:
#                               count
# neighborhood
# Lavapiés-Embajadores             11
# Villaverde Alto                   9
# San Diego                         8
# Valdeacederas                     8
# Los Rosales                       7
# ...                             ...
# Casco Histórico de Vicálvaro      1
# Salvador                          1
# Timón                             1
# Lista                             1
# Concepción                        1
#
# [74 rows x 1 columns]
# La columna hasLift tiene las siguientes valore únicos:
#          count
# hasLift
# True       226
# False      185
# La columna parkingSpace tiene las siguientes valore únicos:
#                                                     count
# parkingSpace
# {'hasParkingSpace': True, 'isParkingSpaceInclud...    130
# {'hasParkingSpace': True, 'isParkingSpaceInclud...      1
# {'hasParkingSpace': True, 'isParkingSpaceInclud...      1
# {'hasParkingSpace': True, 'isParkingSpaceInclud...      1
# {'hasParkingSpace': True, 'isParkingSpaceInclud...      1
# La columna labels tiene las siguientes valore únicos:
#                                                     count
# labels
# [{'name': 'apartamentoType', 'text': 'Apartamen...     30
# La columna newDevelopmentFinished tiene las siguientes valore únicos:
#                         count
# newDevelopmentFinished
# True                        8
# False                       5

# %% [markdown]
# Datos Encontrados:

# %%
df[df['latitude'] == '404.430.651']
# Out:
#      propertyCode  numPhotos  price propertyType operation  size  exterior  \
# 245      98068981         19  692.0         flat      rent  83.0      True
# 246      98069014         19  670.0         flat      rent  79.0      True
# 248      98069020         19  718.0         flat      rent  86.0      True
# 249      98068962         19  694.0         flat      rent  81.0      True
# 250      98069018         19  658.0         flat      rent  78.0      True
# 252      98068997         19  723.0         flat      rent  88.0      True
# 253      98068959         19  728.0         flat      rent  91.0      True
#
#      rooms  bathrooms                   address province       municipality  \
# 245      2          2  Calle Valle de Ambles, 2   Madrid  Torrejón de Ardoz
# 246      2          2  Calle Valle de Ambles, 2   Madrid  Torrejón de Ardoz
# 248      2          2  Calle Valle de Ambles, 2   Madrid  Torrejón de Ardoz
# 249      2          2  Calle Valle de Ambles, 2   Madrid  Torrejón de Ardoz
# 250      2          2  Calle Valle de Ambles, 2   Madrid  Torrejón de Ardoz
# 252      2          2  Calle Valle de Ambles, 2   Madrid  Torrejón de Ardoz
# 253      2          2  Calle Valle de Ambles, 2   Madrid  Torrejón de Ardoz
#
#     country     latitude    longitude  showAddress  distance  \
# 245      es  404.430.651  -34.659.877         True     20294
# 246      es  404.430.651  -34.659.877         True     20294
# 248      es  404.430.651  -34.659.877         True     20294
# 249      es  404.430.651  -34.659.877         True     20294
# 250      es  404.430.651  -34.659.877         True     20294
# 252      es  404.430.651  -34.659.877         True     20294
# 253      es  404.430.651  -34.659.877         True     20294
#
#                                            description hasVideo  \
# 245  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
# 246  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
# 248  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
# 249  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
# 250  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
# 252  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
# 253  VIVIENDA NUEVA PARA ALQUILER ¡Estrena hogar co...    False
#
#              status newDevelopment  priceByArea          detailedType  \
# 245  newdevelopment           True          8.0  {'typology': 'flat'}
# 246  newdevelopment           True          8.0  {'typology': 'flat'}
# 248  newdevelopment           True          8.0  {'typology': 'flat'}
# 249  newdevelopment           True          9.0  {'typology': 'flat'}
# 250  newdevelopment           True          8.0  {'typology': 'flat'}
# 252  newdevelopment           True          8.0  {'typology': 'flat'}
# 253  newdevelopment           True          8.0  {'typology': 'flat'}
#
#                                         suggestedTexts hasPlan has3DTour  \
# 245  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
# 246  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
# 248  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
# 249  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
# 250  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
# 252  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
# 253  {'subtitle': 'Suroeste, Torrejón de Ardoz', 't...    True     False
#
#     has360 hasStaging superTopHighlight topNewDevelopment externalReference  \
# 245  False      False             False             False              VT02
# 246  False      False             False             False              VT07
# 248  False      False             False             False              VT06
# 249  False      False             False             False              VT04
# 250  False      False             False             False              VT05
# 252  False      False             False             False              VT08
# 253  False      False             False             False              VT01
#
#     floor  district neighborhood hasLift  \
# 245   NaN  Suroeste          NaN    True
# 246   NaN  Suroeste          NaN    True
# 248   NaN  Suroeste          NaN    True
# 249   NaN  Suroeste          NaN    True
# 250   NaN  Suroeste          NaN    True
# 252   NaN  Suroeste          NaN    True
# 253   NaN  Suroeste          NaN    True
#
#                                           parkingSpace labels  \
# 245  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 246  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 248  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 249  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 250  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 252  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
# 253  {'hasParkingSpace': True, 'isParkingSpaceInclu...    NaN
#
#     newDevelopmentFinished
# 245                   True
# 246                   True
# 248                   True
# 249                   True
# 250                   True
# 252                   True
# 253                   True

# %% [markdown]
# Encontré los pisos que se encuentran en la misma zona, Torrejón, que forman parte de un condominio.

# %% [markdown]
# Columnas a eliminar:
# - operation: porque habla sobre el tipo, renta, y al final todos son de alquiler. No hace sentido.
# - country: porque todas son de Madrid al final.
# - province: porque al final todas son de Madrid, e incluye valores fuera de Madrid. Debo cargarme esos valores, filas, y esa columna.
# - description: al final no va a interferir ese texto en mi modelo.
# - hasVideo: no me da ninguna información valiosa.
# - newDevelopment: porque al final sus valores ya están determinados por su status.
# - hasPlan: no me interesa ni aporta.
# has3DTour: no me aporta.
# - has360: no me aporta.
# - hasStaging: no me aporta, todas son falsas.
# - superTopHighlights: todas son falsas.
# - topNewDevelopment: todas son falsas.
# - hasParkingSpace: tiene muchos valores nulos.
# - newDevelopmentFinished : apenas tiene 13 valores.
# - labels: tiene más del 90% de nulos.
# - numPhotos: no me parece importante de momento.
# - priceByArea: en sí puede determinar el pronóstico al darme una media del m2 de la zona, si lo relaciono con el tamaño.
# - showAddres: ahora mismo no me aporta.
# - propertyCode: de momento solo me sirvió para distinguir en el tema de duplicados y distintos pisos en la misma zona, ejemplo: residencial.
# - suggestedTexts: viene alimentado por otras columnas.
# - externalReference: eché un ojo al principio pero no me sirve de mucho.
# - addres: no me aporta mucho.
# - latitude/longitude: no me sirven de mucho para mi plan.
# - detailedType: de momento, no me aporta mucho ya que hay otra columna muy similar.

# %% [markdown]
# Eliminar datos que no son de Madrid

# %%
df = df[df['province'] == 'Madrid']

# %%
df.shape
# Out:
# (353, 38)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Eliminar columnas innecesarias

# %%
columnas_eliminar = ['operation', 'province', 'country', 'description',
                    'hasVideo', 'newDevelopment', 'hasPlan', 'has3DTour',
                    'has360','hasStaging', 'superTopHighlight', 
                    'topNewDevelopment', 'parkingSpace','labels',
                    'newDevelopmentFinished', 'numPhotos', 'priceByArea', 'showAddress',
                    'propertyCode', 'suggestedTexts', 
                    'externalReference', 'address', 'latitude', 'longitude', 
                    'detailedType', 'district']

# %%
df.drop(columns=columnas_eliminar, inplace=True)

# %%
df.shape
# Out:
# (353, 12)

# %%
df.describe()
# Out:
#             price        size       rooms   bathrooms      distance
# count  353.000000  353.000000  353.000000  353.000000    353.000000
# mean   692.932011   59.728045    1.543909    1.110482  16698.824363
# std     61.307820   23.799745    0.934760    0.322857  13549.504221
# min    400.000000   20.000000    0.000000    1.000000    183.000000
# 25%    650.000000   45.000000    1.000000    1.000000   5656.000000
# 50%    700.000000   57.000000    2.000000    1.000000  12321.000000
# 75%    740.000000   70.000000    2.000000    1.000000  26558.000000
# max    750.000000  206.000000    4.000000    3.000000  56596.000000

# %%
rooms_0 = df[df['rooms'] == 0]

# %%
rooms_0.head()
# Out:
#     price propertyType  size  exterior  rooms  bathrooms municipality  \
# 4   684.0       studio  45.0      True      0          1       Madrid
# 8   700.0       studio  28.0      True      0          1       Madrid
# 22  750.0       studio  45.0     False      0          1       Madrid
# 27  750.0       studio  25.0     False      0          1       Madrid
# 30  750.0       studio  30.0      True      0          1       Madrid
#
#     distance status floor          neighborhood hasLift
# 4      10656    NaN   NaN                   NaN     NaN
# 8       5569   good     1           San Pascual   False
# 22      1027   good    bj  Lavapiés-Embajadores    True
# 27       533   good     4       Chueca-Justicia    True
# 30       935   good     3  Lavapiés-Embajadores   False

# %% [markdown]
# Estuve revisando los pisos donde la habitación = 0, pero pude comprobar que donde sucede esto es en los estudios.

# %%
df.describe(include='O').T
# Out:
#              count unique                   top freq
# propertyType   353      6                  flat  277
# municipality   353     62                Madrid  170
# status         339      3                  good  324
# floor          290     13                     1   70
# neighborhood   174     74  Lavapiés-Embajadores   11
# hasLift        335      2                  True  174

# %%
df.isna().sum()
# Out:
# price             0
# propertyType      0
# size              0
# exterior          0
# rooms             0
# bathrooms         0
# municipality      0
# distance          0
# status           14
# floor            63
# neighborhood    179
# hasLift          18
# dtype: int64

# %%
sf.exploracion_dataframe(df, 'price')
# Out:
# El número de datos es 353 y el de columnas es 12
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 1
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#                 %_nulos
# status         3.966006
# floor         17.847025
# neighborhood  50.708215
# hasLift        5.099150
#  .....................
#
# Los tipos de las columnas son:
#              tipo_dato
# price          float64
# propertyType    object
# size           float64
# exterior          bool
# rooms            int64
# bathrooms        int64
# municipality    object
# distance         int64
# status          object
# floor           object
# neighborhood    object
# hasLift         object
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna propertyType tiene las siguientes valore únicos:
#               count
# propertyType
# flat            277
# studio           48
# duplex           14
# penthouse        10
# chalet            3
# countryHouse      1
# La columna municipality tiene las siguientes valore únicos:
#                          count
# municipality
# Madrid                     170
# Alcalá de Henares           22
# Parla                       14
# Aranjuez                    11
# Torrejón de Ardoz           11
# ...                        ...
# Daganzo de Arriba            1
# El Álamo                     1
# Algete                       1
# Los Santos de la Humosa      1
# Alcobendas                   1
#
# [62 rows x 1 columns]
# La columna status tiene las siguientes valore únicos:
#                 count
# status
# good              324
# newdevelopment     13
# renew               2
# La columna floor tiene las siguientes valore únicos:
#        count
# floor
# 1         70
# bj        58
# 2         56
# 3         48
# 4         33
# 5          9
# en         6
# 8          4
# 6          2
# st         1
# 7          1
# 14         1
# ss         1
# La columna neighborhood tiene las siguientes valore únicos:
#                               count
# neighborhood
# Lavapiés-Embajadores             11
# Villaverde Alto                   9
# San Diego                         8
# Valdeacederas                     8
# Los Rosales                       7
# ...                             ...
# Casco Histórico de Vicálvaro      1
# Salvador                          1
# Timón                             1
# Lista                             1
# Concepción                        1
#
# [74 rows x 1 columns]
# La columna hasLift tiene las siguientes valore únicos:
#          count
# hasLift
# True       174
# False      161

# %% [markdown]
# Después de un segundo análisis: procedo con los siguientes cambios.

# %%
df.drop(columns='neighborhood', inplace=True)

# %%
df_status = pd.isna(df["status"])
df.loc[df_status, "status"] = 'Desconocido'

# %%
df_floor = pd.isna(df["floor"])
df.loc[df_floor, "floor"] = 'Desconocido'

# %%
# df_dist = pd.isna(df["district"])
# df.loc[df_dist, "district"] = 'Desconocido'

# %%
df_hasL = pd.isna(df["hasLift"])
df.loc[df_hasL, "hasLift"] = 'Desconocido'

# %%
df.isna().sum()
# Out:
# price           0
# propertyType    0
# size            0
# exterior        0
# rooms           0
# bathrooms       0
# municipality    0
# distance        0
# status          0
# floor           0
# hasLift         0
# dtype: int64

# %%
df.dtypes
# Out:
# price           float64
# propertyType     object
# size            float64
# exterior           bool
# rooms             int64
# bathrooms         int64
# municipality     object
# distance          int64
# status           object
# floor            object
# hasLift          object
# dtype: object

# %%
df['rooms'] = df['rooms'].astype('O')
df['bathrooms'] = df['bathrooms'].astype('O')

# %% [markdown]
# # Gráficos

# %%
df_num, df_cat = sf.separar_dataframe(df)

# %%
df_num
# Out:
#      price  size  distance
# 0    750.0  60.0      7037
# 1    750.0  70.0     16145
# 2    400.0  67.0     55041
# 3    590.0  70.0     56596
# 4    684.0  45.0     10656
# ..     ...   ...       ...
# 348  640.0  69.0     29311
# 349  700.0  54.0     11656
# 350  700.0  59.0      7529
# 351  700.0  75.0     30359
# 352  695.0  62.0     15162
#
# [353 rows x 3 columns]

# %%
sf.plot_numericas(df_num)

# %% [markdown]
# Observaciones:
# - Se puede apreciar en la primera gráfica que hay dos picos predominantes, uno en 700 y otro en 750. Destacando que los precios por debajo de 700 son los menos presentes.
# - La mayor parte de los datos se encuentran entre 25 y 100 metros. Más adelante, se pueden observar datos menos presentes en tamaños mayores.
# - En relación a la distancia, hay una predominancia en los valores por debajo de 10,000 metros. A partir de esta, los datos se distribuyen sin seguir ningún patrón específico.
#
# - De igual forma, podemos ver que no hay una distribución normal en estos casos.

# %%
sf.detectar_outliers(df)

# %% [markdown]
# Outliers:
# - En cuanto a precio, se muestran algunos pocos valores por debajo de 500€ como outliers.
# - En cuanto a tamaño, hay una clara concentración entre 25 y 100 m2. Por encima de ahí, se presentan outliers.
# - No hay ningún outlier.

# %%
sf.relacion_numericas(df, 'price')
# Out:
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:164: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=columna,
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:164: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=columna,

# %% [markdown]
# ## Observaciones, relaciones numéricas:
# - Vemos que hay una predominancia en los alquileres a un alto precio son aquellos que se encuentran a una menor distancia del centro. Esto se puede corroborar con la gráfica de abajo, donde se puede apreciar una ligera correlació negativa entre distancia y precio. Esto se traduje a que cuanto más se aleja el precio puede reducirse.

# %%
sns.scatterplot(x='price', y='distance', hue='size', data=df)
# Out:
# <Axes: xlabel='price', ylabel='distance'>

# %%
sns.scatterplot(x='price', y='size', hue='distance', data=df)
# Out:
# <Axes: xlabel='price', ylabel='size'>

# %% [markdown]
# # Pendiente

# %%
df[(df['size'] < 100) & (df['price'] < 500)]
# Out:
#      price propertyType  size  exterior rooms bathrooms  \
# 2    400.0    penthouse  67.0      True     2         2
# 186  450.0    penthouse  60.0      True     1         1
# 241  475.0         flat  79.0      True     2         2
# 339  450.0         flat  40.0      True     1         1
#
#               municipality  distance status        floor hasLift
# 2    Villamanrique de Tajo     55041   good            2   False
# 186        Villa del Prado     53238   good  Desconocido   False
# 241           Navalafuente     45077   good            2    True
# 339     Robledo de Chavela     46273   good            1   False

# %%
df[df['size'] > 150]
# Out:
#      price propertyType   size  exterior rooms bathrooms      municipality  \
# 18   650.0       chalet  206.0     False     3         1  Aldea del Fresno
# 191  660.0         flat  155.0     False     3         2          Aranjuez
# 195  660.0         flat  168.0     False     4         2          Aranjuez
# 225  730.0         flat  161.0      True     4         1          Aranjuez
# 248  600.0       chalet  180.0     False     3         2              Meco
#
#      distance       status        floor      hasLift
# 18      43195         good  Desconocido  Desconocido
# 191     41119  Desconocido  Desconocido  Desconocido
# 195     41221         good            3         True
# 225     44159         good            3        False
# 248     35543         good  Desconocido  Desconocido

# %% [markdown]
# # Pendiente

# %% [markdown]
# Tomando en consideración este último gráfico, se puede apreciar que los pisos de alquiler más cercanos al centro son los más caros. A la vez, estos son los más pequeños. Esto se explica ya que los pisos en el centro de Madrid son cada vez más pequeños debido a la cantidad tan alta de personas. Esto hace que la alta demanda de pisos, convierta cualquier espacio en un piso sin importar su tamaño.
# - También se puede apreciar que aquellos posibles 'pisos grandes' van apareciendo mientras más te alejas de Madrid Centro pero no involucran ser parte de los más costosos.

# %%
df.describe()
# Out:
#             price        size      distance
# count  353.000000  353.000000    353.000000
# mean   692.932011   59.728045  16698.824363
# std     61.307820   23.799745  13549.504221
# min    400.000000   20.000000    183.000000
# 25%    650.000000   45.000000   5656.000000
# 50%    700.000000   57.000000  12321.000000
# 75%    740.000000   70.000000  26558.000000
# max    750.000000  206.000000  56596.000000

# %%
sf.matriz_correacion(df)

# %% [markdown]
# Como ya he mencionado antes, existe una correlación negativa entre precio y distancia. Además hace presencia una correlación positiva entre el tamaño y la distancia.

# %%
sf.plot_categoricas(df_cat)
# Out:
# Index(['propertyType', 'rooms', 'bathrooms', 'municipality', 'status', 'floor',
#        'hasLift'],
#       dtype='object')
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:117: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=columna,
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:117: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=columna,
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:117: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=columna,
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:117: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=columna,
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:117: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=columna,
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:117: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=columna,
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:117: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=columna,

# %%
sf.relacion_vr_categoricas(df,'price')
# Out:
#   propertyType       price
# 3         flat  697.559567
# 5       studio  689.625000
# 2       duplex  689.285714
# 4    penthouse  619.900000
# 0       chalet  610.000000
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna,
#    rooms       price
# 4      4  713.333333
# 3      3  705.230769
# 2      2  697.968750
# 0      0  690.857143
# 1      1  682.652893
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna,
#    bathrooms       price
# 2          3  750.000000
# 0          1  694.552381
# 1          2  677.594595
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna,
#                municipality  price
# 47  San Fernando de Henares  750.0
# 4                    Algete  750.0
# 50    Serranillos del Valle  750.0
# 25      Las Rozas de Madrid  750.0
# 9                Campo Real  750.0
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna,
#            status       price
# 1            good  695.243827
# 2  newdevelopment  676.307692
# 0     Desconocido  662.428571
# 3           renew  640.000000
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna,
#    floor  price
# 1     14  750.0
# 7      7  750.0
# 13    st  750.0
# 6      6  725.0
# 8      8  723.0
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna,
#        hasLift       price
# 1         True  702.252874
# 0        False  687.633540
# 2  Desconocido  650.222222
# c:\Users\DELL\Git\Proyecto7---Proyecto-Regresi-n-Lineal\Modelo_2\..\src\soporte_funciones.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna,

# %%
lista_col = df_cat.columns.tolist()

# %%
sf.visualizar_categoricas(df,lista_col,'price')

# %% [markdown]
# ## Imputación:
# - No he imputado como tal ya que mis valores no se alejan mucho de la realidad.

# %%
df.isna().sum()
# Out:
# price           0
# propertyType    0
# size            0
# exterior        0
# rooms           0
# bathrooms       0
# municipality    0
# distance        0
# status          0
# floor           0
# hasLift         0
# dtype: int64

# %%
df.to_csv('../datos_2/datos_limpios.csv')

# %%
df.head()
# Out:
#    price propertyType  size  exterior rooms bathrooms  \
# 0  750.0         flat  60.0      True     1         1
# 1  750.0         flat  70.0      True     2         1
# 2  400.0    penthouse  67.0      True     2         2
# 3  590.0         flat  70.0      True     3         2
# 4  684.0       studio  45.0      True     0         1
#
#                  municipality  distance       status        floor      hasLift
# 0                      Madrid      7037         good            3         True
# 1  San Sebastián de los Reyes     16145         good           bj        False
# 2       Villamanrique de Tajo     55041         good            2        False
# 3                   Rascafría     56596         good  Desconocido        False
# 4                      Madrid     10656  Desconocido  Desconocido  Desconocido
